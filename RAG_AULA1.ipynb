# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavol3ma/Learning_journey/blob/main/RAG_AULA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai pypdf
# !pip install langchain-community

# %%
import os
from google.colab import userdata
os.environ["GOOGLE_API_KEY"] = userdata.get('APY_RAG')

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash', temperature= 0)

# %%
#EXEMPLO 01: PROMPTING TRADICIONAL (SEM RAG)
pergunta = 'Qual é a política de home office de nossa empresa?'

prompt_tradicional = ChatPromptTemplate.from_template(
    'Responda a seguinte pergunta: {pergunta}'
)

chain_tradicional = prompt_tradicional | llm

resposta_tradicional = chain_tradicional.invoke({'pergunta': pergunta})
print(resposta_tradicional.content)
# Out:
# Como uma inteligência artificial, eu não tenho acesso às políticas internas específicas da sua empresa. Para responder a essa pergunta com precisão, eu precisaria saber a qual empresa você se refere, pois as políticas de home office variam muito de uma organização para outra.
#
# No entanto, posso te dar uma visão geral dos tipos mais comuns de políticas de home office e **onde você pode encontrar essa informação na sua empresa**:
#
# ### Tipos Comuns de Políticas de Home Office:
#
# 1.  **Home Office Total / Remoto (Full Remote):**
#     *   **Descrição:** Todos os colaboradores trabalham exclusivamente de casa ou de qualquer outro local remoto. A empresa pode ter um escritório físico, mas ele não é o local principal de trabalho.
#     *   **Características:** Grande flexibilidade, foco em resultados, comunicação assíncrona e ferramentas digitais robustas.
#
# 2.  **Modelo Híbrido:**
# ...
